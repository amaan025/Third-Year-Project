# %% [markdown]
# Capturing Images through videos

# %%
import cv2
import os

def capture_frames_from_folder(input_folder, output_folder, frame_interval=10):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith((".mp4", ".avi", ".mkv")):
            video_path = os.path.join(input_folder, filename)

            # Open the video file
            cap = cv2.VideoCapture(video_path)

            # Initialize frame count
            frame_count = 0

            # Loop through the video frames
            while True:
                # Read a frame from the video
                ret, frame = cap.read()

                # Break the loop if the video has ended
                if not ret:
                    break

                # Save frames at specified intervals
                if frame_count % frame_interval == 0:
                    # Construct the output image filename
                    output_filename = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}_frame_{frame_count // frame_interval}.jpg")

                    # Save the frame as an image
                    cv2.imwrite(output_filename, frame)

                # Increment the frame count
                frame_count += 1

            # Release the video capture object
            cap.release()

# Example usage
input_folder = "C:/Users/almeen fatima/Desktop/Third year project/new_video"
output_folder = "C:/Users/almeen fatima/Desktop/Third year project/new_images"
capture_frames_from_folder(input_folder, output_folder, frame_interval=10)

# %% [markdown]
# Image pre-processing

# %%
import cv2
import os

def preprocess_images(input_folder, output_folder, target_size=(224, 224)):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each image in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith((".jpg", ".jpeg", ".png")):
            # Read the image
            img_path = os.path.join(input_folder, filename)
            img = cv2.imread(img_path)

            # Resize the image to the target size
            img = cv2.resize(img, target_size)

            # Save the preprocessed image to the output folder
            output_path = os.path.join(output_folder, filename)
            cv2.imwrite(output_path, img)

# Example usage
input_folder = "C:/Users/almeen fatima/Desktop/Third year project/input_folder"
output_folder = "C:/Users/almeen fatima/Desktop/Third year project/output_folder"
preprocess_images(input_folder, output_folder)

# %% [markdown]
# Data Augumentation

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

def augment_images(input_folder, output_folder, augment_factor=5):
    # Create an ImageDataGenerator with desired augmentations
    datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
       # horizontal_flip=True,
       # vertical_flip=True,  # Add vertical flip
        brightness_range=[0.5, 1.5],  # Adjust brightness
        channel_shift_range=50.0,  # Random channel shifts
        zoom_range=[0.8, 1.2],  # Random zoom
        fill_mode='nearest'
    )

    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each image in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith((".jpg", ".jpeg", ".png")):
            img_path = os.path.join(input_folder, filename)

            # Load the image
            img = load_img(img_path)
            x = img_to_array(img)
            x = x.reshape((1,) + x.shape)

            # Generate augmented images and save them
            i = 0
            for batch in datagen.flow(x, batch_size=1, save_to_dir=output_folder, save_prefix='aug', save_format='jpeg'):
                i += 1
                if i >= augment_factor:
                    break  # Break the loop after generating the desired number of augmented images

# Example usage
input_folder = "E:/Desktop/Third year project/iigg"
output_folder = "E:/Desktop/Third year project/skimg_aug"
augment_images(input_folder, output_folder, augment_factor=5)

# %%
import os

# Get the absolute path of the current working directory
current_working_directory = os.getcwd()

print("Current Working Directory:", current_working_directory)
# Out:
# Current Working Directory: e:\Desktop\Third year project

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data="config.yml", epochs=20)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.1.14 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.9 🚀 Python-3.9.7 torch-2.2.0+cpu CPU (11th Gen Intel Core(TM) i5-1155G7 2.50GHz)
# engine\trainer: task=detect, mode=train, model=yolov8n.yaml, data=config.yml, epochs=20, time=None, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train8, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train8
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLOv8n summary: 225 layers, 3011043 parameters, 3011027 gradients, 8.2 GFLOPs
#
# TensorBoard: Start with 'tensorboard --logdir runs\detect\train8', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning E:\Desktop\Third year project\data\labels.cache... 1575 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1575/1575 [00:00<?, ?it/s]
# val: Scanning E:\Desktop\Third year project\data\labels.cache... 1575 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1575/1575 [00:00<?, ?it/s]
# Plotting labels to runs\detect\train8\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs\detect\train8
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20         0G      2.912       3.27      3.827         23        640: 100%|██████████| 99/99 [13:51<00:00,  8.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:41<00:00,  5.63s/it]
#                    all       1575       1575      0.266     0.0902      0.257     0.0862
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20         0G      2.304      2.128      2.848         17        640: 100%|██████████| 99/99 [12:37<00:00,  7.65s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:11<00:00,  5.03s/it]
#                    all       1575       1575      0.764      0.755      0.857      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20         0G      1.839      1.521      2.318         19        640: 100%|██████████| 99/99 [12:17<00:00,  7.45s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:13<00:00,  5.08s/it]
#                    all       1575       1575      0.917      0.915      0.963      0.468
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20         0G      1.627      1.286      2.087         16        640: 100%|██████████| 99/99 [12:13<00:00,  7.41s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:10<00:00,  5.01s/it]
#                    all       1575       1575       0.92       0.93      0.976      0.561
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20         0G      1.557      1.116      1.967         17        640: 100%|██████████| 99/99 [12:17<00:00,  7.45s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:09<00:00,  4.99s/it]
#                    all       1575       1575      0.967      0.973      0.991      0.639
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20         0G      1.464      1.044      1.877         17        640: 100%|██████████| 99/99 [12:17<00:00,  7.45s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:08<00:00,  4.97s/it]
#                    all       1575       1575      0.944      0.947      0.987      0.702
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20         0G      1.386     0.9634      1.798         16        640: 100%|██████████| 99/99 [12:16<00:00,  7.44s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:10<00:00,  5.00s/it]
#                    all       1575       1575      0.973       0.98       0.99      0.725
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20         0G      1.333     0.9185      1.723         18        640: 100%|██████████| 99/99 [12:18<00:00,  7.45s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:10<00:00,  5.01s/it]
#                    all       1575       1575      0.985       0.98      0.994      0.699
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20         0G      1.341     0.8813      1.713         10        640: 100%|██████████| 99/99 [12:15<00:00,  7.43s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:10<00:00,  5.00s/it]
#                    all       1575       1575      0.979      0.988      0.992      0.729
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20         0G      1.236     0.7922      1.621         15        640: 100%|██████████| 99/99 [12:15<00:00,  7.43s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:05<00:00,  4.92s/it]
#                    all       1575       1575      0.984      0.993      0.994      0.733
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20         0G      1.051     0.6284      1.442          7        640: 100%|██████████| 99/99 [12:10<00:00,  7.38s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:23<00:00,  5.28s/it]
#                    all       1575       1575      0.979      0.984      0.994      0.725
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20         0G      1.007     0.5884      1.407          7        640: 100%|██████████| 99/99 [12:08<00:00,  7.36s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:07<00:00,  4.96s/it]
#                    all       1575       1575      0.968      0.971      0.991      0.745
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20         0G     0.9543     0.5445      1.375          7        640: 100%|██████████| 99/99 [12:03<00:00,  7.31s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:09<00:00,  4.99s/it]
#                    all       1575       1575      0.992      0.992      0.994      0.787
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20         0G     0.9314      0.508       1.34          7        640: 100%|██████████| 99/99 [12:01<00:00,  7.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:16<00:00,  5.12s/it]
#                    all       1575       1575      0.996      0.994      0.994      0.794
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20         0G     0.8912     0.4903      1.319          7        640: 100%|██████████| 99/99 [12:14<00:00,  7.42s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:08<00:00,  4.96s/it]
#                    all       1575       1575      0.989      0.993      0.994      0.789
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20         0G      0.891     0.4857      1.306          7        640: 100%|██████████| 99/99 [12:03<00:00,  7.31s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:07<00:00,  4.96s/it]
#                    all       1575       1575      0.991      0.998      0.994       0.79
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20         0G      0.881     0.4712      1.287          7        640: 100%|██████████| 99/99 [12:03<00:00,  7.30s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:14<00:00,  5.10s/it]
#                    all       1575       1575      0.997      0.992      0.994      0.807
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20         0G     0.8514     0.4465      1.273          7        640: 100%|██████████| 99/99 [12:05<00:00,  7.32s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:08<00:00,  4.98s/it]
#                    all       1575       1575      0.997      0.994      0.995      0.807
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20         0G     0.8391     0.4373      1.267          7        640: 100%|██████████| 99/99 [12:03<00:00,  7.30s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:07<00:00,  4.95s/it]
#                    all       1575       1575       0.99      0.997      0.994      0.808
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20         0G     0.8233     0.4272      1.251          7        640: 100%|██████████| 99/99 [12:04<00:00,  7.32s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [04:09<00:00,  4.99s/it]
#                    all       1575       1575      0.996      0.996      0.994      0.823
# 20 epochs completed in 5.500 hours.
# Optimizer stripped from runs\detect\train8\weights\last.pt, 6.2MB
# Optimizer stripped from runs\detect\train8\weights\best.pt, 6.2MB
#
# Validating runs\detect\train8\weights\best.pt...
# Ultralytics YOLOv8.1.9 🚀 Python-3.9.7 torch-2.2.0+cpu CPU (11th Gen Intel Core(TM) i5-1155G7 2.50GHz)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [05:08<00:00,  6.18s/it]
#                    all       1575       1575      0.996      0.996      0.994      0.823
# Speed: 2.4ms preprocess, 133.2ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs\detect\train8

# %%
# from ultralytics import YOLO
# import cv2

# # Load the trained model
# model = YOLO("yolov8n.yaml")  # Load the trained model weights and configuration

# # Set up real-time object detection
# cap = cv2.VideoCapture(0)  # Open the webcam or any video source

# while True:
#     ret, frame = cap.read()  # Read a frame from the video source
#     if not ret:
#         break

#     # Perform object detection on the frame
#     results = model(frame)

#     # Extract the bounding boxes, labels, and scores
#     boxes = results.xyxy[0][:, :4]
#     confidences = results.xyxy[0][:, 4]
#     class_ids = results.xyxy[0][:, 5]

#     # Loop through the detections and draw bounding boxes
#     for box, confidence, class_id in zip(boxes, confidences, class_ids):
#         x1, y1, x2, y2 = map(int, box)
#         cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
#         label = f"{model.names[int(class_id)]}: {confidence:.2f}"
#         cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

#     # Display the frame with bounding boxes
#     cv2.imshow('Object Detection', frame)

#     # Exit on pressing 'q'
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# # Release resources
# cap.release()
# cv2.destroyAllWindows()

# %%
from ultralytics import YOLO
import cv2

# Load the trained model
model = YOLO("yolov8n.yaml")  # Load the trained model weights and configuration

# Set up real-time object detection
cap = cv2.VideoCapture(0)  # Open the webcam or any video source

while True:
    ret, frame = cap.read()  # Read a frame from the video source
    if not ret:
        break

    # Perform object detection on the frame
    results = model(frame)

    # Display the results
    results.show()

    # Exit on pressing 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()

# %%
import os

from ultralytics import YOLO
import cv2


VIDEOS_DIR = os.path.join('.', 'video_postbox')

video_path = os.path.join(VIDEOS_DIR, 'v6.mp4')
video_path_out = '{}_out2.mp4'.format(video_path)

cap = cv2.VideoCapture(video_path)
ret, frame = cap.read()
H, W, _ = frame.shape
out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*'MP4V'), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))

model_path = os.path.join('.', 'runs', 'detect', 'train8', 'weights', 'last.pt')

# Load a model
model = YOLO(model_path)  # load a custom model

threshold = 0.5

while ret:

    results = model(frame)[0]

    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
            cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)

    out.write(frame)
    ret, frame = cap.read()

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 postbox, 77.3ms
# Speed: 4.0ms preprocess, 77.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 73.6ms
# Speed: 2.0ms preprocess, 73.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 75.9ms
# Speed: 2.0ms preprocess, 75.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 65.2ms
# Speed: 1.0ms preprocess, 65.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 60.0ms
# Speed: 2.4ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 59.8ms
# Speed: 1.0ms preprocess, 59.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 71.9ms
# Speed: 1.3ms preprocess, 71.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 71.2ms
# Speed: 2.0ms preprocess, 71.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 67.2ms
# Speed: 3.0ms preprocess, 67.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 67.9ms
# Speed: 1.0ms preprocess, 67.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 65.5ms
# Speed: 2.0ms preprocess, 65.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 71.5ms
# Speed: 1.2ms preprocess, 71.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 72.4ms
# Speed: 2.4ms preprocess, 72.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 63.4ms
# Speed: 1.0ms preprocess, 63.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 66.5ms
# Speed: 1.0ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 58.3ms
# Speed: 2.0ms preprocess, 58.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 66.9ms
# Speed: 2.0ms preprocess, 66.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 65.7ms
# Speed: 2.4ms preprocess, 65.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 64.6ms
# Speed: 2.1ms preprocess, 64.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 63.0ms
# Speed: 2.4ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 65.0ms
# Speed: 1.0ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 59.3ms
# Speed: 2.5ms preprocess, 59.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 54.9ms
# Speed: 2.0ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 63.1ms
# Speed: 2.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 60.4ms
# Speed: 2.0ms preprocess, 60.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 56.4ms
# Speed: 1.9ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 55.7ms
# Speed: 1.0ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 63.1ms
# Speed: 1.0ms preprocess, 63.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 60.6ms
# Speed: 2.0ms preprocess, 60.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 60.2ms
# Speed: 1.0ms preprocess, 60.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 69.6ms
# Speed: 2.2ms preprocess, 69.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 69.1ms
# Speed: 2.0ms preprocess, 69.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 68.1ms
# Speed: 2.4ms preprocess, 68.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 65.2ms
# Speed: 1.1ms preprocess, 65.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 65.3ms
# Speed: 1.0ms preprocess, 65.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 59.9ms
# Speed: 1.2ms preprocess, 59.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 68.2ms
# Speed: 1.0ms preprocess, 68.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 67.2ms
# Speed: 2.0ms preprocess, 67.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 64.4ms
# Speed: 2.0ms preprocess, 64.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 67.9ms
# Speed: 1.0ms preprocess, 67.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 55.4ms
# Speed: 1.0ms preprocess, 55.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 61.4ms
# Speed: 2.0ms preprocess, 61.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 78.8ms
# Speed: 2.2ms preprocess, 78.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 107.5ms
# Speed: 1.0ms preprocess, 107.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 82.2ms
# Speed: 2.0ms preprocess, 82.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 66.9ms
# Speed: 2.6ms preprocess, 66.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 56.8ms
# Speed: 1.0ms preprocess, 56.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 62.7ms
# Speed: 2.4ms preprocess, 62.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 60.0ms
# Speed: 1.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 62.5ms
# Speed: 1.4ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 57.5ms
# Speed: 2.1ms preprocess, 57.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 60.7ms
# Speed: 1.0ms preprocess, 60.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 56.9ms
# Speed: 1.0ms preprocess, 56.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 50.7ms
# Speed: 2.0ms preprocess, 50.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 54.9ms
# Speed: 1.0ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 61.3ms
# Speed: 2.5ms preprocess, 61.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 58.6ms
# Speed: 2.4ms preprocess, 58.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 58.7ms
# Speed: 2.1ms preprocess, 58.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 55.7ms
# Speed: 1.0ms preprocess, 55.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 62.4ms
# Speed: 2.0ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 55.4ms
# Speed: 2.5ms preprocess, 55.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 62.1ms
# Speed: 2.0ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 67.0ms
# Speed: 1.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 68.6ms
# Speed: 2.0ms preprocess, 68.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 65.5ms
# Speed: 2.3ms preprocess, 65.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 75.3ms
# Speed: 2.0ms preprocess, 75.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 66.3ms
# Speed: 2.0ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 56.6ms
# Speed: 2.0ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 66.3ms
# Speed: 2.0ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 67.7ms
# Speed: 2.0ms preprocess, 67.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 62.3ms
# Speed: 2.1ms preprocess, 62.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 63.5ms
# Speed: 1.0ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 62.3ms
# Speed: 2.0ms preprocess, 62.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 55.7ms
# Speed: 1.0ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 52.9ms
# Speed: 3.6ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 63.9ms
# Speed: 2.0ms preprocess, 63.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 62.8ms
# Speed: 3.0ms preprocess, 62.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 62.4ms
# Speed: 2.3ms preprocess, 62.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 65.1ms
# Speed: 1.3ms preprocess, 65.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 58.1ms
# Speed: 3.0ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 65.9ms
# Speed: 2.0ms preprocess, 65.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 67.0ms
# Speed: 2.3ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 63.6ms
# Speed: 2.0ms preprocess, 63.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 60.2ms
# Speed: 3.0ms preprocess, 60.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 62.5ms
# Speed: 2.3ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 54.8ms
# Speed: 2.4ms preprocess, 54.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 69.0ms
# Speed: 2.4ms preprocess, 69.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 59.7ms
# Speed: 1.0ms preprocess, 59.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 56.7ms
# Speed: 1.1ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 60.7ms
# Speed: 2.1ms preprocess, 60.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 67.4ms
# Speed: 2.5ms preprocess, 67.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 62.1ms
# Speed: 2.0ms preprocess, 62.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 53.9ms
# Speed: 2.1ms preprocess, 53.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 53.8ms
# Speed: 2.0ms preprocess, 53.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 56.5ms
# Speed: 2.3ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 63.0ms
# Speed: 2.2ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 68.3ms
# Speed: 1.0ms preprocess, 68.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 55.2ms
# Speed: 2.0ms preprocess, 55.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 58.2ms
# Speed: 2.1ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 65.8ms
# Speed: 1.2ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 71.8ms
# Speed: 2.0ms preprocess, 71.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 62.4ms
# Speed: 3.0ms preprocess, 62.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 66.7ms
# Speed: 1.5ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 69.6ms
# Speed: 19.6ms preprocess, 69.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 67.3ms
# Speed: 3.5ms preprocess, 67.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 73.8ms
# Speed: 2.1ms preprocess, 73.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 73.8ms
# Speed: 1.0ms preprocess, 73.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 68.5ms
# Speed: 1.0ms preprocess, 68.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 67.3ms
# Speed: 3.1ms preprocess, 67.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 64.4ms
# Speed: 2.2ms preprocess, 64.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 70.4ms
# Speed: 2.0ms preprocess, 70.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 72.3ms
# Speed: 2.0ms preprocess, 72.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 77.4ms
# Speed: 1.0ms preprocess, 77.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 74.8ms
# Speed: 1.0ms preprocess, 74.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 68.1ms
# Speed: 1.1ms preprocess, 68.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 60.3ms
# Speed: 3.0ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 78.6ms
# Speed: 3.0ms preprocess, 78.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 83.2ms
# Speed: 2.0ms preprocess, 83.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 88.2ms
# Speed: 3.0ms preprocess, 88.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 82.3ms
# Speed: 3.0ms preprocess, 82.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 85.0ms
# Speed: 2.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 87.7ms
# Speed: 2.1ms preprocess, 87.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 86.6ms
# Speed: 3.1ms preprocess, 86.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 76.4ms
# Speed: 2.1ms preprocess, 76.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 73.2ms
# Speed: 3.0ms preprocess, 73.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 84.5ms
# Speed: 3.2ms preprocess, 84.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 72.1ms
# Speed: 3.0ms preprocess, 72.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 72.6ms
# Speed: 2.1ms preprocess, 72.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 88.8ms
# Speed: 3.2ms preprocess, 88.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 69.6ms
# Speed: 2.0ms preprocess, 69.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 82.3ms
# Speed: 3.0ms preprocess, 82.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 95.1ms
# Speed: 2.1ms preprocess, 95.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 83.4ms
# Speed: 2.7ms preprocess, 83.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 76.0ms
# Speed: 3.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 77.0ms
# Speed: 2.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 85.0ms
# Speed: 3.0ms preprocess, 85.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 77.1ms
# Speed: 3.0ms preprocess, 77.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 81.4ms
# Speed: 2.0ms preprocess, 81.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 75.4ms
# Speed: 2.0ms preprocess, 75.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 86.3ms
# Speed: 2.0ms preprocess, 86.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 83.9ms
# Speed: 2.0ms preprocess, 83.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 79.5ms
# Speed: 2.5ms preprocess, 79.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 89.2ms
# Speed: 2.0ms preprocess, 89.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 81.2ms
# Speed: 2.0ms preprocess, 81.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 76.0ms
# Speed: 2.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 83.5ms
# Speed: 3.0ms preprocess, 83.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 70.8ms
# Speed: 3.0ms preprocess, 70.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 82.8ms
# Speed: 3.0ms preprocess, 82.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 77.5ms
# Speed: 3.2ms preprocess, 77.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 77.6ms
# Speed: 3.0ms preprocess, 77.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 76.5ms
# Speed: 2.0ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 89.4ms
# Speed: 3.1ms preprocess, 89.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 78.7ms
# Speed: 3.0ms preprocess, 78.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 75.0ms
# Speed: 2.0ms preprocess, 75.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 74.6ms
# Speed: 3.0ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 71.1ms
# Speed: 3.0ms preprocess, 71.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 79.3ms
# Speed: 3.0ms preprocess, 79.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 81.2ms
# Speed: 2.3ms preprocess, 81.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 78.7ms
# Speed: 2.0ms preprocess, 78.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 61.7ms
# Speed: 3.0ms preprocess, 61.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 83.3ms
# Speed: 2.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 77.3ms
# Speed: 2.3ms preprocess, 77.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 72.7ms
# Speed: 4.0ms preprocess, 72.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 72.2ms
# Speed: 2.0ms preprocess, 72.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 83.1ms
# Speed: 3.1ms preprocess, 83.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 73.9ms
# Speed: 2.1ms preprocess, 73.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 86.2ms
# Speed: 2.0ms preprocess, 86.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 78.5ms
# Speed: 3.1ms preprocess, 78.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 82.1ms
# Speed: 3.0ms preprocess, 82.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 73.3ms
# Speed: 2.4ms preprocess, 73.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 81.1ms
# Speed: 3.3ms preprocess, 81.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 70.1ms
# Speed: 3.0ms preprocess, 70.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 110.1ms
# Speed: 2.0ms preprocess, 110.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 83.2ms
# Speed: 2.1ms preprocess, 83.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 71.3ms
# Speed: 3.1ms preprocess, 71.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 78.7ms
# Speed: 3.0ms preprocess, 78.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 80.7ms
# Speed: 2.5ms preprocess, 80.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 85.2ms
# Speed: 2.1ms preprocess, 85.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 84.4ms
# Speed: 2.1ms preprocess, 84.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 78.5ms
# Speed: 3.3ms preprocess, 78.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 78.5ms
# Speed: 3.1ms preprocess, 78.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 78.1ms
# Speed: 2.0ms preprocess, 78.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 81.0ms
# Speed: 3.1ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 73.7ms
# Speed: 2.0ms preprocess, 73.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 77.9ms
# Speed: 2.0ms preprocess, 77.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 74.5ms
# Speed: 2.2ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 75.2ms
# Speed: 2.5ms preprocess, 75.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 70.4ms
# Speed: 3.5ms preprocess, 70.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 79.9ms
# Speed: 2.1ms preprocess, 79.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 83.8ms
# Speed: 2.0ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 81.4ms
# Speed: 2.1ms preprocess, 81.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 73.6ms
# Speed: 3.5ms preprocess, 73.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 82.0ms
# Speed: 2.8ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 67.2ms
# Speed: 3.5ms preprocess, 67.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 85.0ms
# Speed: 2.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 80.3ms
# Speed: 2.5ms preprocess, 80.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 77.6ms
# Speed: 3.3ms preprocess, 77.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 76.0ms
# Speed: 2.3ms preprocess, 76.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 84.0ms
# Speed: 3.0ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 70.6ms
# Speed: 3.0ms preprocess, 70.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 78.5ms
# Speed: 3.0ms preprocess, 78.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 82.6ms
# Speed: 2.0ms preprocess, 82.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 80.9ms
# Speed: 3.1ms preprocess, 80.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 79.7ms
# Speed: 2.0ms preprocess, 79.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 84.0ms
# Speed: 2.4ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 80.5ms
# Speed: 2.0ms preprocess, 80.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 80.0ms
# Speed: 2.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 80.7ms
# Speed: 2.5ms preprocess, 80.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 81.7ms
# Speed: 3.2ms preprocess, 81.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 84.5ms
# Speed: 3.4ms preprocess, 84.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 72.5ms
# Speed: 3.0ms preprocess, 72.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 81.1ms
# Speed: 3.0ms preprocess, 81.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 75.0ms
# Speed: 3.0ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 78.9ms
# Speed: 2.0ms preprocess, 78.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 81.0ms
# Speed: 2.0ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 81.1ms
# Speed: 3.0ms preprocess, 81.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 74.4ms
# Speed: 3.4ms preprocess, 74.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 66.4ms
# Speed: 2.0ms preprocess, 66.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 75.7ms
# Speed: 2.0ms preprocess, 75.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 83.5ms
# Speed: 2.0ms preprocess, 83.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 79.2ms
# Speed: 2.4ms preprocess, 79.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 82.5ms
# Speed: 2.0ms preprocess, 82.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 71.0ms
# Speed: 3.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 82.0ms
# Speed: 3.0ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 72.5ms
# Speed: 3.0ms preprocess, 72.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 77.3ms
# Speed: 2.0ms preprocess, 77.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 69.7ms
# Speed: 2.0ms preprocess, 69.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 78.0ms
# Speed: 3.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 75.8ms
# Speed: 4.0ms preprocess, 75.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 68.5ms
# Speed: 3.0ms preprocess, 68.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 78.0ms
# Speed: 3.1ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 89.9ms
# Speed: 2.1ms preprocess, 89.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 80.6ms
# Speed: 2.0ms preprocess, 80.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 86.0ms
# Speed: 3.5ms preprocess, 86.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 74.4ms
# Speed: 3.0ms preprocess, 74.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 73.9ms
# Speed: 3.2ms preprocess, 73.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 80.9ms
# Speed: 3.4ms preprocess, 80.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 64.6ms
# Speed: 2.0ms preprocess, 64.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 69.6ms
# Speed: 4.1ms preprocess, 69.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 76.5ms
# Speed: 2.0ms preprocess, 76.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 75.7ms
# Speed: 2.0ms preprocess, 75.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 70.6ms
# Speed: 2.0ms preprocess, 70.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 postboxs, 77.2ms
# Speed: 2.4ms preprocess, 77.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 postboxs, 80.0ms
# Speed: 2.0ms preprocess, 80.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 postboxs, 73.1ms
# Speed: 2.0ms preprocess, 73.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 80.6ms
# Speed: 2.3ms preprocess, 80.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 78.5ms
# Speed: 2.0ms preprocess, 78.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 68.4ms
# Speed: 2.0ms preprocess, 68.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 82.9ms
# Speed: 2.0ms preprocess, 82.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 73.2ms
# Speed: 4.1ms preprocess, 73.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 77.4ms
# Speed: 2.0ms preprocess, 77.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 70.6ms
# Speed: 3.0ms preprocess, 70.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 77.8ms
# Speed: 2.0ms preprocess, 77.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 82.0ms
# Speed: 2.0ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 73.3ms
# Speed: 2.1ms preprocess, 73.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 72.1ms
# Speed: 2.0ms preprocess, 72.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 74.4ms
# Speed: 2.0ms preprocess, 74.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 76.7ms
# Speed: 2.2ms preprocess, 76.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 87.8ms
# Speed: 2.8ms preprocess, 87.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 88.7ms
# Speed: 2.3ms preprocess, 88.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 87.9ms
# Speed: 2.4ms preprocess, 87.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 83.4ms
# Speed: 2.0ms preprocess, 83.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 86.1ms
# Speed: 3.0ms preprocess, 86.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 84.4ms
# Speed: 3.0ms preprocess, 84.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 101.4ms
# Speed: 4.0ms preprocess, 101.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 107.4ms
# Speed: 4.0ms preprocess, 107.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 82.3ms
# Speed: 3.0ms preprocess, 82.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 81.2ms
# Speed: 2.0ms preprocess, 81.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 83.0ms
# Speed: 3.0ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 79.0ms
# Speed: 3.2ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 81.8ms
# Speed: 2.4ms preprocess, 81.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 78.8ms
# Speed: 3.1ms preprocess, 78.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 73.7ms
# Speed: 2.0ms preprocess, 73.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 82.1ms
# Speed: 2.2ms preprocess, 82.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 81.6ms
# Speed: 3.4ms preprocess, 81.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 81.5ms
# Speed: 3.4ms preprocess, 81.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 75.3ms
# Speed: 3.2ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 79.4ms
# Speed: 3.0ms preprocess, 79.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 74.3ms
# Speed: 1.0ms preprocess, 74.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 71.5ms
# Speed: 2.2ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 76.5ms
# Speed: 3.0ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 79.9ms
# Speed: 2.1ms preprocess, 79.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 81.0ms
# Speed: 2.3ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 84.2ms
# Speed: 2.2ms preprocess, 84.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 82.4ms
# Speed: 2.5ms preprocess, 82.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 80.2ms
# Speed: 3.2ms preprocess, 80.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 82.7ms
# Speed: 2.5ms preprocess, 82.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 64.5ms
# Speed: 2.2ms preprocess, 64.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 82.9ms
# Speed: 3.5ms preprocess, 82.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 71.2ms
# Speed: 3.0ms preprocess, 71.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 71.2ms
# Speed: 3.0ms preprocess, 71.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 75.3ms
# Speed: 3.2ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 76.2ms
# Speed: 3.1ms preprocess, 76.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 81.8ms
# Speed: 3.0ms preprocess, 81.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 76.6ms
# Speed: 2.0ms preprocess, 76.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 75.4ms
# Speed: 2.0ms preprocess, 75.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 63.9ms
# Speed: 2.5ms preprocess, 63.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 76.2ms
# Speed: 2.0ms preprocess, 76.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 77.6ms
# Speed: 2.4ms preprocess, 77.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 73.8ms
# Speed: 2.5ms preprocess, 73.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 86.3ms
# Speed: 3.0ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 83.0ms
# Speed: 3.3ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 86.3ms
# Speed: 3.3ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 89.6ms
# Speed: 3.3ms preprocess, 89.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 83.7ms
# Speed: 3.0ms preprocess, 83.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 77.7ms
# Speed: 3.0ms preprocess, 77.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 80.5ms
# Speed: 3.0ms preprocess, 80.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 78.1ms
# Speed: 4.4ms preprocess, 78.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 78.4ms
# Speed: 3.0ms preprocess, 78.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 78.3ms
# Speed: 3.0ms preprocess, 78.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 80.7ms
# Speed: 2.4ms preprocess, 80.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 77.7ms
# Speed: 3.0ms preprocess, 77.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 78.8ms
# Speed: 2.0ms preprocess, 78.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 86.2ms
# Speed: 2.0ms preprocess, 86.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 94.7ms
# Speed: 3.2ms preprocess, 94.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 91.8ms
# Speed: 2.7ms preprocess, 91.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 90.8ms
# Speed: 2.0ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 91.2ms
# Speed: 2.5ms preprocess, 91.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 80.8ms
# Speed: 4.2ms preprocess, 80.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 84.1ms
# Speed: 2.0ms preprocess, 84.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 73.6ms
# Speed: 2.0ms preprocess, 73.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 83.8ms
# Speed: 3.0ms preprocess, 83.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 84.5ms
# Speed: 3.0ms preprocess, 84.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 79.7ms
# Speed: 3.1ms preprocess, 79.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 71.0ms
# Speed: 3.3ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 80.3ms
# Speed: 2.0ms preprocess, 80.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 80.6ms
# Speed: 2.4ms preprocess, 80.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 77.9ms
# Speed: 2.7ms preprocess, 77.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 76.0ms
# Speed: 2.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 81.4ms
# Speed: 2.0ms preprocess, 81.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 postboxs, 73.2ms
# Speed: 3.0ms preprocess, 73.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 78.2ms
# Speed: 2.4ms preprocess, 78.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 82.6ms
# Speed: 2.0ms preprocess, 82.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 67.5ms
# Speed: 3.0ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 80.3ms
# Speed: 2.4ms preprocess, 80.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 78.3ms
# Speed: 2.0ms preprocess, 78.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 68.9ms
# Speed: 4.4ms preprocess, 68.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 71.1ms
# Speed: 2.0ms preprocess, 71.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 72.2ms
# Speed: 2.2ms preprocess, 72.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 67.5ms
# Speed: 3.0ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 75.3ms
# Speed: 2.0ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 postboxs, 73.6ms
# Speed: 3.0ms preprocess, 73.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 101.2ms
# Speed: 5.5ms preprocess, 101.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 82.0ms
# Speed: 2.0ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 83.5ms
# Speed: 2.0ms preprocess, 83.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 86.4ms
# Speed: 2.0ms preprocess, 86.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 80.0ms
# Speed: 2.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 73.8ms
# Speed: 2.0ms preprocess, 73.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 79.7ms
# Speed: 2.4ms preprocess, 79.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 80.7ms
# Speed: 3.0ms preprocess, 80.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 80.0ms
# Speed: 2.6ms preprocess, 80.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 80.7ms
# Speed: 3.0ms preprocess, 80.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 78.4ms
# Speed: 3.0ms preprocess, 78.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 72.6ms
# Speed: 2.5ms preprocess, 72.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 74.3ms
# Speed: 3.2ms preprocess, 74.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 79.4ms
# Speed: 3.2ms preprocess, 79.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 68.8ms
# Speed: 2.0ms preprocess, 68.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 75.2ms
# Speed: 2.2ms preprocess, 75.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 postboxs, 84.2ms
# ...
# Speed: 2.5ms preprocess, 90.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 90.3ms
# Speed: 2.0ms preprocess, 90.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 94.5ms
# Speed: 4.0ms preprocess, 94.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 91.7ms
# Speed: 4.0ms preprocess, 91.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 117.3ms
# Speed: 2.3ms preprocess, 117.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 102.4ms
# Speed: 3.4ms preprocess, 102.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 79.1ms
# Speed: 3.0ms preprocess, 79.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 94.3ms
# Speed: 3.2ms preprocess, 94.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 97.4ms
# Speed: 3.1ms preprocess, 97.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 87.9ms
# Speed: 3.1ms preprocess, 87.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 93.3ms
# Speed: 3.0ms preprocess, 93.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 88.5ms
# Speed: 3.0ms preprocess, 88.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 132.9ms
# Speed: 3.1ms preprocess, 132.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 89.5ms
# Speed: 2.0ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 82.6ms
# Speed: 3.0ms preprocess, 82.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 99.8ms
# Speed: 2.0ms preprocess, 99.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 96.0ms
# Speed: 4.2ms preprocess, 96.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 91.8ms
# Speed: 2.0ms preprocess, 91.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 121.2ms
# Speed: 3.5ms preprocess, 121.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 97.0ms
# Speed: 4.0ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 88.7ms
# Speed: 2.4ms preprocess, 88.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 86.5ms
# Speed: 4.0ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 87.7ms
# Speed: 3.0ms preprocess, 87.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 86.4ms
# Speed: 4.1ms preprocess, 86.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 95.3ms
# Speed: 3.5ms preprocess, 95.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 90.0ms
# Speed: 3.3ms preprocess, 90.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 125.0ms
# Speed: 3.2ms preprocess, 125.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 94.4ms
# Speed: 2.0ms preprocess, 94.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 75.7ms
# Speed: 3.0ms preprocess, 75.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 97.1ms
# Speed: 3.4ms preprocess, 97.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 81.5ms
# Speed: 4.0ms preprocess, 81.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 99.8ms
# Speed: 3.3ms preprocess, 99.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 129.8ms
# Speed: 8.0ms preprocess, 129.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 140.3ms
# Speed: 2.4ms preprocess, 140.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 postbox, 111.9ms
# Speed: 3.0ms preprocess, 111.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 106.2ms
# Speed: 3.2ms preprocess, 106.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.2ms
# Speed: 2.2ms preprocess, 99.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.7ms
# Speed: 2.3ms preprocess, 104.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 100.3ms
# Speed: 3.1ms preprocess, 100.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 115.8ms
# Speed: 2.0ms preprocess, 115.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 113.1ms
# Speed: 3.0ms preprocess, 113.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 117.3ms
# Speed: 4.0ms preprocess, 117.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.2ms
# Speed: 3.0ms preprocess, 98.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 94.4ms
# Speed: 3.0ms preprocess, 94.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 117.0ms
# Speed: 3.0ms preprocess, 117.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.6ms
# Speed: 3.6ms preprocess, 98.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 92.4ms
# Speed: 2.1ms preprocess, 92.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 134.5ms
# Speed: 3.0ms preprocess, 134.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 113.8ms
# Speed: 3.4ms preprocess, 113.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.0ms
# Speed: 3.5ms preprocess, 99.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 102.1ms
# Speed: 3.0ms preprocess, 102.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 119.7ms
# Speed: 2.0ms preprocess, 119.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.2ms
# Speed: 3.4ms preprocess, 98.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 100.8ms
# Speed: 2.0ms preprocess, 100.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.8ms
# Speed: 3.0ms preprocess, 95.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.1ms
# Speed: 4.3ms preprocess, 89.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 132.4ms
# Speed: 3.1ms preprocess, 132.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 131.1ms
# Speed: 3.0ms preprocess, 131.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.6ms
# Speed: 3.0ms preprocess, 99.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 100.4ms
# Speed: 3.0ms preprocess, 100.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 102.8ms
# Speed: 3.0ms preprocess, 102.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 106.4ms
# Speed: 2.1ms preprocess, 106.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 109.0ms
# Speed: 3.4ms preprocess, 109.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 140.0ms
# Speed: 3.0ms preprocess, 140.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.6ms
# Speed: 10.4ms preprocess, 101.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 91.0ms
# Speed: 3.0ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 106.3ms
# Speed: 2.6ms preprocess, 106.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 124.6ms
# Speed: 5.0ms preprocess, 124.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 108.0ms
# Speed: 3.8ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 113.4ms
# Speed: 3.3ms preprocess, 113.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 142.7ms
# Speed: 2.0ms preprocess, 142.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 106.3ms
# Speed: 3.2ms preprocess, 106.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.3ms
# Speed: 3.0ms preprocess, 99.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 116.1ms
# Speed: 4.0ms preprocess, 116.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.8ms
# Speed: 2.4ms preprocess, 99.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 120.3ms
# Speed: 3.4ms preprocess, 120.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 110.7ms
# Speed: 3.0ms preprocess, 110.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 134.1ms
# Speed: 3.8ms preprocess, 134.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 113.2ms
# Speed: 3.5ms preprocess, 113.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 120.1ms
# Speed: 3.0ms preprocess, 120.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 113.9ms
# Speed: 3.4ms preprocess, 113.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.1ms
# Speed: 2.2ms preprocess, 149.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 107.6ms
# Speed: 2.4ms preprocess, 107.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 106.0ms
# Speed: 3.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 100.1ms
# Speed: 4.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.0ms
# Speed: 10.0ms preprocess, 104.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.3ms
# Speed: 2.3ms preprocess, 98.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.4ms
# Speed: 3.0ms preprocess, 104.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 94.3ms
# Speed: 3.0ms preprocess, 94.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.9ms
# Speed: 3.0ms preprocess, 95.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 134.6ms
# Speed: 32.1ms preprocess, 134.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 83.0ms
# Speed: 2.5ms preprocess, 83.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.5ms
# Speed: 2.0ms preprocess, 85.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 97.9ms
# Speed: 8.1ms preprocess, 97.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 125.3ms
# Speed: 3.3ms preprocess, 125.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 127.1ms
# Speed: 4.3ms preprocess, 127.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 110.6ms
# Speed: 3.4ms preprocess, 110.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.5ms
# Speed: 3.0ms preprocess, 157.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 131.3ms
# Speed: 4.5ms preprocess, 131.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 100.7ms
# Speed: 3.0ms preprocess, 100.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.3ms
# Speed: 3.7ms preprocess, 98.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.2ms
# Speed: 4.2ms preprocess, 87.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.6ms
# Speed: 3.0ms preprocess, 99.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 93.5ms
# Speed: 2.0ms preprocess, 93.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 110.8ms
# Speed: 4.0ms preprocess, 110.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 86.4ms
# Speed: 6.2ms preprocess, 86.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.9ms
# Speed: 3.3ms preprocess, 104.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 96.9ms
# Speed: 3.2ms preprocess, 96.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 96.8ms
# Speed: 3.3ms preprocess, 96.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.1ms
# Speed: 3.0ms preprocess, 89.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 97.4ms
# Speed: 3.0ms preprocess, 97.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 116.6ms
# Speed: 2.5ms preprocess, 116.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.1ms
# Speed: 2.1ms preprocess, 79.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 86.3ms
# Speed: 5.0ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.7ms
# Speed: 3.0ms preprocess, 87.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.6ms
# Speed: 2.3ms preprocess, 82.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 91.4ms
# Speed: 3.0ms preprocess, 91.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 93.1ms
# Speed: 2.1ms preprocess, 93.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 113.0ms
# Speed: 3.8ms preprocess, 113.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.5ms
# Speed: 2.0ms preprocess, 81.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.7ms
# Speed: 2.0ms preprocess, 84.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
import os
import cv2
from ultralytics import YOLO
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score

# Paths
VIDEOS_DIR = os.path.join('.', 'video_postbox')
TEST_IMAGES_DIR = os.path.join('.', 'test_images')

# Load the model
model_path = os.path.join('.', 'runs', 'detect', 'train8', 'weights', 'last.pt')
model = YOLO(model_path)

# Threshold
threshold = 0.5

# Initialize lists to store evaluation results
true_positives = 0
false_positives = 0
false_negatives = 0

def calculate_iou(box1, box2):
    """
    Calculate IoU (Intersection over Union) between two bounding boxes.
    """
    x1_tl, y1_tl, x1_br, y1_br = box1
    x2_tl, y2_tl, x2_br, y2_br = box2
    
    # Calculate intersection area
    x_tl = max(x1_tl, x2_tl)
    y_tl = max(y1_tl, y2_tl)
    x_br = min(x1_br, x2_br)
    y_br = min(y1_br, y2_br)
    
    intersection_area = max(0, x_br - x_tl + 1) * max(0, y_br - y_tl + 1)
    
    # Calculate area of each bounding box
    box1_area = (x1_br - x1_tl + 1) * (y1_br - y1_tl + 1)
    box2_area = (x2_br - x2_tl + 1) * (y2_br - y2_tl + 1)
    
    # Calculate union area
    union_area = box1_area + box2_area - intersection_area
    
    # Calculate IoU
    iou = intersection_area / union_area
    
    return iou

# Loop through test images
for img_file in os.listdir(TEST_IMAGES_DIR):
    if img_file.endswith('.jpg') or img_file.endswith('.png'):
        img_path = os.path.join(TEST_IMAGES_DIR, img_file)
        image = cv2.imread(img_path)
        results = model(image)

        # Ground truth annotations (you need to replace this with your actual ground truth data)
        # ground_truth_boxes = ... (format: [x1, y1, x2, y2, class_id] for each ground truth box)
        
        # Your code to load ground truth annotations for this image
        ground_truth_boxes = [...]  # Replace [...] with your ground truth annotations

        # Extract predicted bounding boxes from results
        pred_boxes = results.xyxy[0].cpu().numpy()  # Assuming batch size is 1

        # Match predicted boxes with ground truth boxes
        for pred_box in pred_boxes:
            pred_x1, pred_y1, pred_x2, pred_y2, score, class_id = pred_box

            # Filter predictions based on confidence threshold
            if score > threshold:
                # Your code to check if this prediction matches any ground truth box
                # For simplicity, let's assume a simple IoU-based matching
                matched = False
                for gt_box in ground_truth_boxes:
                    iou = calculate_iou(pred_box[:4], gt_box[:4])
                    if iou > 0.5 and class_id == gt_box[4]:
                        true_positives += 1
                        matched = True
                        break
                if not matched:
                    false_positives += 1

        # Count false negatives (ground truth boxes not matched with any prediction)
        for gt_box in ground_truth_boxes:
            gt_matched = False
            for pred_box in pred_boxes:
                iou = calculate_iou(pred_box[:4], gt_box[:4])
                if iou > 0.5 and pred_box[5] == gt_box[4]:
                    gt_matched = True
                    break
            if not gt_matched:
                false_negatives += 1

# Calculate evaluation metrics
precision = true_positives / (true_positives + false_positives)
recall = true_positives / (true_positives + false_negatives)
f1 = 2 * (precision * recall) / (precision + recall)

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# %%
import os
import cv2
import numpy as np

def skew_image(image, angle):
    """
    Skew the input image by the given angle.
    """
    height, width = image.shape[:2]
    # Define the skew matrix
    skew_matrix = np.float32([[1, np.tan(np.radians(angle)), 0],
                              [0, 1, 0]])
    # Apply the skew transformation
    skewed_image = cv2.warpAffine(image, skew_matrix, (width, height), borderMode=cv2.BORDER_REFLECT)
    return skewed_image

def main(input_folder, output_folder, angle_range=(-10, 10), num_samples_per_image=5):
    """
    Skew images from the input folder and save the skewed images to the output folder.
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through each image in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(('.jpg', '.jpeg', '.png')):
            input_path = os.path.join(input_folder, filename)
            output_path_prefix = os.path.join(output_folder, os.path.splitext(filename)[0])

            # Load the image
            image = cv2.imread(input_path)

            # Skew the image multiple times with random angles within the specified range
            for i in range(num_samples_per_image):
                angle = np.random.uniform(angle_range[0], angle_range[1])
                skewed_image = skew_image(image, angle)

                # Save the skewed image
                output_path = f"{output_path_prefix}_skewed_{i}.jpg"
                cv2.imwrite(output_path, skewed_image)
                print(f"Skewed image saved: {output_path}")

if __name__ == "__main__":
    input_folder = "E:/Desktop/Third year project/new_images"
    output_folder = "E:/Desktop/Third year project/skimg"
    angle_range = (-10, 10)  # Range of angles for skewing
    num_samples_per_image = 5  # Number of skewed images to generate per input image

    main(input_folder, output_folder, angle_range, num_samples_per_image)
# Out:
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0003_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0003_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0003_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0003_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0003_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0004_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0004_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0004_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0004_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0004_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0005_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0005_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0005_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0005_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0005_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0006_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0006_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0006_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0006_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240206-WA0006_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0015_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0015_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0015_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0015_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0015_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0016_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0016_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0016_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0016_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0016_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0017_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0017_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0017_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0017_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0017_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0018_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0018_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0018_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0018_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0018_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0019_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0019_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0019_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0019_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0019_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0020_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0020_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0020_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0020_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0020_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0021_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0021_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0021_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0021_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0021_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0022_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0022_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0022_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0022_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0022_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0023_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0023_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0023_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0023_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0023_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0024_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0024_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0024_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0024_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0024_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0025_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0025_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0025_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0025_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0025_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0026_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0026_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0026_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0026_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0026_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0027_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0027_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0027_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0027_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0027_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0028_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0028_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0028_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0028_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0028_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0029_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0029_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0029_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0029_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0029_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0030_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0030_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0030_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0030_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0030_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0031_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0031_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0031_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0031_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0031_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0032_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0032_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0032_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0032_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0032_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0033_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0033_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0033_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0033_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0033_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0034_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0034_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0034_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0034_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0034_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0035_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0035_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0035_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0035_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0035_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0036_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0036_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0036_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0036_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0036_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0037_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0037_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0037_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0037_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0037_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0038_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0038_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0038_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0038_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0038_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0039_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0039_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0039_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0039_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0039_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0040_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0040_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0040_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0040_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0040_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0041_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0041_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0041_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0041_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0041_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0042_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0042_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0042_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0042_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0042_skewed_4.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0043_skewed_0.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0043_skewed_1.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0043_skewed_2.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0043_skewed_3.jpg
# Skewed image saved: E:/Desktop/Third year project/skimg\IMG-20240208-WA0043_skewed_4.jpg
